# %%
import requests
from bs4 import BeautifulSoup

# %% [markdown]
# Requests: GET,POST,PUT,PATCH,DELETE

# %%
page = requests.get("https://somon.tj/transport/legkovyie-avtomobili/toyota/camry/year_max---2018/year_min---2005/dushanbe/?type_view=card")

# %%
page.status_code
# Out:
# 200

# %%
page.content.decode("utf-8")
# Out:
# '<!doctype html>\n<html lang="ru">\n<head>\n  \n  \n  <meta charset="UTF-8">\n  <meta content="telephone=no" name="format-detection">\n  <link rel="icon" href="https://somon.tj/static/favicons/favicon.e6a7156b2f04.ico" type="image/x-icon">\n  <link rel="shortcut icon" href="https://somon.tj/static/favicons/favicon.e6a7156b2f04.ico" type="image/x-icon">\n  \n  <link rel="apple-touch-icon" href="https://somon.tj/static/images/app-icons/somon/57.1912ed90dc1b.png" />\n  <link rel="apple-touch-icon" sizes="57x57" href="https://somon.tj/static/images/app-icons/somon/57.1912ed90dc1b.png" />\n  <link rel="apple-touch-icon" sizes="72x72" href="https://somon.tj/static/images/app-icons/somon/72.aeaaad48587e.png" />\n  <link rel="apple-touch-icon" sizes="114x114" href="https://somon.tj/static/images/app-icons/somon/114.598447f73ebb.png" />\n  <link rel="apple-touch-icon" sizes="120x120" href="https://somon.tj/static/images/app-icons/somon/120.3d1f299619d6.png" />\n  <link rel="apple-touch-icon" 
# ...

# %%
soup = BeautifulSoup(page.content,"html.parser")

# %%
print(soup.prettify)
# Out:
# <bound method Tag.prettify of <!DOCTYPE html>
#
# <html lang="ru">
# <head>
# <meta charset="utf-8"/>
# <meta content="telephone=no" name="format-detection"/>
# <link href="https://somon.tj/static/favicons/favicon.e6a7156b2f04.ico" rel="icon" type="image/x-icon"/>
# <link href="https://somon.tj/static/favicons/favicon.e6a7156b2f04.ico" rel="shortcut icon" type="image/x-icon"/>
# <link href="https://somon.tj/static/images/app-icons/somon/57.1912ed90dc1b.png" rel="apple-touch-icon">
# <link href="https://somon.tj/static/images/app-icons/somon/57.1912ed90dc1b.png" rel="apple-touch-icon" sizes="57x57">
# <link href="https://somon.tj/static/images/app-icons/somon/72.aeaaad48587e.png" rel="apple-touch-icon" sizes="72x72"/>
# <link href="https://somon.tj/static/images/app-icons/somon/114.598447f73ebb.png" rel="apple-touch-icon" sizes="114x114"/>
# <link href="https://somon.tj/static/images/app-icons/somon/120.3d1f299619d6.png" rel="apple-touch-icon" sizes="120x120"/>
# ...

# %%
items = soup.find_all("div",class_="card__title")

# %%
items
# Out:
# [<div class="card__title">
#  <a class="card__title-link" content="Toyota Camry, 2011" href="/adv/7577399_toyota-camry-2011/" itemprop="name">
#            Toyota Camry, 2011
#          </a>
#  <span class="card__title-price" itemprop="offers" itemscope="" itemtype="http://schema.org/Offer">
#  <meta content="Toyota Camry, 2011" itemprop="name"/>
#  <meta content="Душанбе" itemprop="areaServed"/>
#  <meta content="TJS" itemprop="priceCurrency"/>
#  <meta content="150000.00" itemprop="price"/>
#              150 000 <b>c.</b> <span class="announcement-block__discount-start">165 000 <b>c.</b></span>
#  </span>
#  <div class="alif _listing">
#  <span class="alif__label">В кредит</span>
#  <span class="alif__price">3132 c./мес.</span>
#  </div>
#  </div>,
#  <div class="card__title">
#  <a class="card__title-link" content="Toyota Camry, 2008" href="/adv/8125464_toyota-camry-2008/" itemprop="name">
#            Toyota Camry, 2008
#          </a>
# ...

# %%
len(items)
# Out:
# 64

# %%
item = items[5]

# %%
item
# Out:
# <div class="card__title">
# <a class="card__title-link" content="Toyota Camry, 2012" href="/adv/7670304_toyota-camry-2012/" itemprop="name">
#         Toyota Camry, 2012
#       </a>
# <span class="card__title-price" itemprop="offers" itemscope="" itemtype="http://schema.org/Offer">
# <meta content="Toyota Camry, 2012" itemprop="name">
# <meta content="Душанбе" itemprop="areaServed">
# <meta content="TJS" itemprop="priceCurrency"/>
# <meta content="155000.00" itemprop="price"/>
#           155 000 <b>c.</b>
# </meta></meta></span>
# <div class="alif _listing">
# <span class="alif__label">В кредит</span>
# <span class="alif__price">3236 c./мес.</span>
# </div>
# </div>

# %%
item.contents[3:5]
# Out:
# [<span class="card__title-price" itemprop="offers" itemscope="" itemtype="http://schema.org/Offer">
#  <meta content="Toyota Camry, 2012" itemprop="name">
#  <meta content="Душанбе" itemprop="areaServed">
#  <meta content="TJS" itemprop="priceCurrency"/>
#  <meta content="155000.00" itemprop="price"/>
#            155 000 <b>c.</b>
#  </meta></meta></span>,
#  '\n']

# %%
this_item = item.find_all("meta")

# %%
this_item
# Out:
# [<meta content="Toyota Camry, 2012" itemprop="name">
#  <meta content="Душанбе" itemprop="areaServed">
#  <meta content="TJS" itemprop="priceCurrency"/>
#  <meta content="155000.00" itemprop="price"/>
#            155 000 <b>c.</b>
#  </meta></meta>,
#  <meta content="Душанбе" itemprop="areaServed">
#  <meta content="TJS" itemprop="priceCurrency"/>
#  <meta content="155000.00" itemprop="price"/>
#            155 000 <b>c.</b>
#  </meta>,
#  <meta content="TJS" itemprop="priceCurrency"/>,
#  <meta content="155000.00" itemprop="price"/>]

# %%
this_item[3]
# Out:
# <meta content="155000.00" itemprop="price"/>

# %%
for this_item in items:
    prices = this_item.find_all("meta")[3]
    print(prices)
# Out:
# <meta content="150000.00" itemprop="price"/>
# <meta content="90000.00" itemprop="price"/>
# <meta content="95999.00" itemprop="price"/>
# <meta content="135000.00" itemprop="price"/>
# <meta content="152000.00" itemprop="price"/>
# <meta content="155000.00" itemprop="price"/>
# <meta content="120000.00" itemprop="price"/>
# <meta content="149000.00" itemprop="price"/>
# <meta content="136000.00" itemprop="price"/>
# <meta content="86000.00" itemprop="price"/>
# <meta content="83000.00" itemprop="price"/>
# <meta content="150000.00" itemprop="price"/>
# <meta content="110000.00" itemprop="price"/>
# <meta content="345000.00" itemprop="price"/>
# <meta content="115000.00" itemprop="price"/>
# <meta content="138000.00" itemprop="price"/>
# <meta content="135000.00" itemprop="price"/>
# <meta content="125000.00" itemprop="price"/>
# <meta content="143000.00" itemprop="price"/>
# <meta content="90000.00" itemprop="price"/>
# <meta content="90000.00" itemprop="price"/>
# ...

# %%
def get_somontj(page):
    cars=[]
    page = requests.get("https://somon.tj/transport/legkovyie-avtomobili/toyota/camry/year_max---2018/year_min---2005/dushanbe/?type_view=card&page="+str(page))
    soup = BeautifulSoup(page.content,"html.parser")
    for this_item in items:
        prices = this_item.find_all("meta")[3]
        cars.append(str(prices))
    return cars

# %%
first_page=get_somontj(0)

# %%
int(first_page[1][15:20])
# Out:
# 90000
